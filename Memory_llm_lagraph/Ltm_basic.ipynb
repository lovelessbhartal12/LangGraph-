# %%
from langgraph.graph import StateGraph
from langgraph.store.memory import InMemoryStore

# %%
store=InMemoryStore()

# %%
namespace=("user" , "u1")

# %% [markdown]
# creating memory

# %%
store.put(namespace, "1", {"data":"user like volleyball"})
store.put(namespace, "2", {"data":"user like football"})

# %%
namespace2=("user" , "u2")

store.put(namespace2, "1", {"data":"user like coding"})
store.put(namespace2, "2", {"data":"user like darkmode"})

# %% [markdown]
# Retriving memory

# %%
store.get(namespace2, "1")
# Out:
# Item(namespace=['user', 'u2'], key='1', value={'data': 'user like coding'}, created_at='2026-02-04T14:08:22.293669+00:00', updated_at='2026-02-04T14:08:22.293671+00:00')

# %% [markdown]
# Retriving all memory

# %%
items=store.search(namespace2)  

for item in items:
    print(item.value)
# Out:
# {'data': 'user like coding'}
# {'data': 'user like darkmode'}

# %% [markdown]
# Semantic search

# %%
from langchain_ollama import OllamaEmbeddings

embeddings=OllamaEmbeddings(model="phi3:mini")

# %%
store=InMemoryStore(index={'embed':embeddings})

# %%
namespace3=("user","u3")

# %%
store.put(namespace3, "1", {"data": "User prefers concise answers over long explanations"})
store.put(namespace3, "2", {"data": "User likes examples in Python"})
store.put(namespace3, "3", {"data": "User usually works late at night"})
store.put(namespace3, "4", {"data": "User prefers dark mode in applications"})
store.put(namespace3, "5", {"data": "User is learning machine learning"})
store.put(namespace3, "6", {"data": "User dislikes overly theoretical explanations"})
store.put(namespace3, "7", {"data": "User prefers step-by-step reasoning"})
store.put(namespace3, "8", {"data": "User is based in India"})
store.put(namespace3, "9", {"data": "User likes real-world analogies"})
store.put(namespace3, "10", {"data": "User prefers bullet points over paragraphs"})

# %%
items=store.search(namespace3, query="what is user currently learning ", limit=3)

# %%
for item in items:
    print(item.value)
# Out:
# {'data': 'User is learning machine learning'}
# {'data': 'User usually works late at night'}
# {'data': 'User is based in India'}
